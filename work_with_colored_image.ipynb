# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('images.jpeg')
img_color=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.imshow(img_color)

# %%
img_color_new=img_color[50:200,40:200,:]
plt.imshow(img_color_new)

# %%
img_color_resize=cv2.resize(img_color,(25,25))

# %%
plt.imshow(img_color_resize)
